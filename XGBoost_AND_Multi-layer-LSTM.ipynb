# %%
import pandas as pd
import numpy as np
import string
from sklearn.model_selection import train_test_split, cross_val_score,GridSearchCV, RandomizedSearchCV
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.pipeline import Pipeline

# %%
from wordcloud import WordCloud
from nltk.corpus import stopwords
from textblob import Word, TextBlob
from nltk.sentiment import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from nltk.stem import WordNetLemmatizer
import spacy

import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /opt/conda/lib/python3.10/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

import warnings
warnings.filterwarnings("ignore")

pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_rows', 55)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
import pandas as pd
from datasets import load_dataset

# Завантаження датасету
dataset = load_dataset('mavinsao/reddit-mental-illness-82')
df = dataset['train'].to_pandas()

# Перетворення тексту на нижній регістр
df['text'] = df['text'].str.lower()

# Фільтрація рядків за наявністю ключових слів
keywords = [
    "think i have", "i think i have", "i think it might be", "i think i could have",
    "might have", "i might have", "might be", "feel like i have", "i feel like i have",
    "feels like i have", "self-diagnose", "self-diagnosed", "i've self-diagnosed",
    "unsure if i have", "i'm unsure if", "unsure if this is", "wonder if i have",
    "i wonder if i have", "wonder if it's", "symptoms of", "i have symptoms of",
    "experiencing symptoms of", "suspect i have", "i suspect i have", "i suspect it's",
    "probably have", "i probably have", "i think i probably have", "could be", "it could be",
    "seems like i have", "it seems like i have", "it seems like", "not diagnosed but",
    "i am not diagnosed but", "i haven't been diagnosed but"
]

df = df[~df['text'].str.contains('|'.join(keywords), case=False, na=False)]

# Розбиття тексту на заголовок і основний текст
def split_text(row):
    if ':' in row:
        parts = row.split(':', 1)
        return parts[0].strip(), parts[1].strip()
    return None, row.strip()

df[['title', 'main_text']] = df['text'].apply(split_text).apply(pd.Series)

# Перевірка результату
print(df[['title', 'main_text', 'label']])
# Out:
# Downloading readme:   0%|          | 0.00/755 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/24.2M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.03M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.04M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/42113 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/5264 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/5265 [00:00<?, ? examples/s]
#                                                    title  \
# 0                              fantasizing about your fp
# 1      this is a support subreddit for people with a ...
# 2                        scared of my psychotic symptoms
# 4      i feel like a sick animal that needs to be put...
# 5      is constantly checking ocd subreddits a compul...
# ...                                                  ...
# 42108  16m suicidal, lonely, need to feel loved befor...
# 42109                               got asked on a date!
# 42110         i just found out my friend killed herself.
# 42111  family letter detailing the conditions and lib...
# 42112                     i'm very proud of myself today
#
#                                                main_text  label
# 0      do you do it? what do you fantasize about? : w...      3
# 1      it's not for posting how infuriating the uneve...      6
# 2      i'm trying to keep reminding myself that what ...      2
# 4      i had a cat for 18 years. at the end of her li...      4
# 5      i kid you not, when i have the thoughts, i’m c...      6
# ...                                                  ...    ...
# 42108  don't really know why i'm making this post, i ...      4
# 42109  and by a girl i already liked. pretty excited ...      1
# 42110  i had been trying to get her through this suic...      3
# 42111  this post is in relation to a post discussing ...      5
# 42112  i had an exam today and my anxiety started kic...      3
#
# [38469 rows x 3 columns]

# %%
import pandas as pd
from nltk.corpus import stopwords
import spacy

# Функція очищення тексту
def clean_text(text):
    text = text.str.lower()
    text = text.str.replace(r'[^\w\s]', '', regex=True)
    text = text.str.replace("\n", '', regex=True)
    text = text.str.replace('\d', '', regex=True)
    text = text.str.replace(r'\[.*?\]', '', regex=True)
    text = text.str.replace(r'https?://\S+|www\.\S+', '', regex=True)
    text = text.str.replace(r'<.*?>+', '', regex=True)
    text = text.str.replace(r'\w*\d\w*', '', regex=True)
    return text

# Функція видалення стоп-слів
# custom_stopwords = {'ocd', 'anxiety', 'adhd', 'ptsd', 'bpd', 'depression', 'bipolar'}
custom_stopwords = {}
def remove_stopwords(text):
    stop_words = set(stopwords.words('english'))
    stop_words.update(custom_stopwords)
    text = text.apply(lambda x: " ".join(word for word in str(x).split() if word.lower() not in stop_words))
    return text

# Функція лематизації
nlp = spacy.load('en_core_web_sm')

def lemmatize_sentence(sentence):
    doc = nlp(sentence)
    return " ".join([token.lemma_ for token in doc])

# Застосування функцій до обох стовпців
def process_text_columns(df, columns):
    for col in columns:
        df[col] = clean_text(df[col])
        df[col] = remove_stopwords(df[col])
        delete = pd.Series(' '.join(df[col]).split()).value_counts()[-1000:]
        df[col] = df[col].apply(lambda x: " ".join(word for word in x.split() if word.lower() not in delete))
        df[col] = df[col].apply(lemmatize_sentence)
    return df

df = pd.DataFrame(df)
df = process_text_columns(df, ['title', 'main_text'])
print(df)
# Out:
#                                                     text  label  \
# 0      fantasizing about your fp: do you do it? what ...      3
# 1      this is a support subreddit for people with a ...      6
# 2      scared of my psychotic symptoms : i'm trying t...      2
# 4      i feel like a sick animal that needs to be put...      4
# 5      is constantly checking ocd subreddits a compul...      6
# ...                                                  ...    ...
# 42108  16m suicidal, lonely, need to feel loved befor...      4
# 42109  got asked on a date! : and by a girl i already...      1
# 42110  i just found out my friend killed herself. : i...      3
# 42111  family letter detailing the conditions and lib...      5
# 42112  i'm very proud of myself today : i had an exam...      3
#
#                                                    title  \
# 0                                           fantasize fp
# 1                support subreddit people mental illness
# 2                               scared psychotic symptom
# 4                         feel like sick animal need put
# 5              constantly check ocd subreddit compulsion
# ...                                                  ...
# 42108  suicidal lonely need feel loved end tonight ne...
# 42109                                       get ask date
# 42110                                   find friend kill
# 42111  family letter condition liberation concentrati...
# 42112                                    I m proud today
#
#                                                main_text
# 0      fantasize fp attract fp romantic way fantasize...
# 1      post infuriate uneven floor tile satisfy candy...
# 2      I m try keep remind I m think believe be not r...
# 4      cat year end life lose mental faculty lethargi...
# 5      kid thought I m constantly check ocd subreddit...
# ...                                                  ...
# 42108  do not really know I m make post do not want a...
# 42109  girl already like pretty excited time seem mis...
# 42110  try get suicidality get medicare would not let...
# 42111  post relation post discuss holocaust another s...
# 42112  exam today anxiety start kick last night speak...
#
# [38469 rows x 4 columns]

# %%
import pandas as pd
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import train_test_split




# Об'єднання заголовку і основного тексту в один стовпець
df['text'] = df['title'].str.strip(':') + ' ' + df['main_text']
# df['text'] = df['main_text']
X = df['text']
y = df['label']

undersampler = RandomUnderSampler(sampling_strategy='auto', random_state=42)
X_res, y_res = undersampler.fit_resample(X.values.reshape(-1, 1), y)

# Перевірка, чи вдалося збалансувати класи
print("Розподіл класів після балансування:")
print(pd.Series(y_res).value_counts())

balanced_df = pd.DataFrame({
    'text': X_res.flatten(),
    'label': y_res
})

# тренувальний та тестовий набори
train_df, test_df = train_test_split(balanced_df, test_size=0.2, random_state=42)

print("\nРозподіл класів у тренувальному наборі:")
print(train_df['label'].value_counts())

print("\nРозподіл класів у тестовому наборі:")
print(test_df['label'].value_counts())
# Out:
# Розподіл класів після балансування:
# label
# 0    3257
# 1    3257
# 2    3257
# 3    3257
# 4    3257
# 5    3257
# 6    3257
# 7    3257
# Name: count, dtype: int64
#
# Розподіл класів у тренувальному наборі:
# label
# 5    2624
# 3    2622
# 7    2616
# 6    2615
# 0    2615
# 4    2604
# 1    2586
# 2    2562
# Name: count, dtype: int64
#
# Розподіл класів у тестовому наборі:
# label
# 2    695
# 1    671
# 4    653
# 0    642
# 6    642
# 7    641
# 3    635
# 5    633
# Name: count, dtype: int64

# %%
from xgboost import XGBClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import ParameterGrid
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder

# Трансформація тексту в TF-IDF вектори
tfidf_vectorizer = TfidfVectorizer()
X_train = tfidf_vectorizer.fit_transform(train_df['text'])
X_test = tfidf_vectorizer.transform(test_df['text'])

# Перетворення текстових міток у числові значення
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(train_df['label'])
y_test = label_encoder.transform(test_df['label'])

# гіперпараметри для перебору
grid_params = {
    'max_depth': [3, 6, 9],
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.05, 0.1]
}


param_grid = list(ParameterGrid(grid_params))
best_accuracy = 0
best_params = None

for params in param_grid:
    print(f"Training with parameters: {params}")
    xgb_classifier = XGBClassifier(
        random_state=42,
        use_label_encoder=False,
        **params
    )
    xgb_classifier.fit(X_train, y_train)

    y_test_pred = xgb_classifier.predict(X_test)
    accuracy = accuracy_score(y_test, y_test_pred)
    print(f"Accuracy: {accuracy}")

    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_params = params

print("\nBest Parameters:", best_params)
print("Best Test Set Accuracy:", best_accuracy)
# Out:
# Training with parameters: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}
# Accuracy: 0.6841903300076746
# Training with parameters: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}
# Accuracy: 0.695510360706063
# Training with parameters: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300}
# Accuracy: 0.7052954719877207
# Training with parameters: {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 100}
# Accuracy: 0.7102839600920952
# Training with parameters: {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 200}
# Accuracy: 0.7229470452801228
# Training with parameters: {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 300}
# Accuracy: 0.7338833461243285
# Training with parameters: {'learning_rate': 0.01, 'max_depth': 9, 'n_estimators': 100}
# Accuracy: 0.7262087490406753
# Training with parameters: {'learning_rate': 0.01, 'max_depth': 9, 'n_estimators': 200}
# Accuracy: 0.7352264006139677
# Training with parameters: {'learning_rate': 0.01, 'max_depth': 9, 'n_estimators': 300}
# Accuracy: 0.7440521872601689
# Training with parameters: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Accuracy: 0.7227551803530314
# Training with parameters: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}
# Accuracy: 0.7519186492709132
# Training with parameters: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 300}
# Accuracy: 0.7666922486569455
# Training with parameters: {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 100}
# Accuracy: 0.7482732156561781
# Training with parameters: {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 200}
# Accuracy: 0.7674597083653109
# Training with parameters: {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 300}
# Accuracy: 0.7789716039907905
# Training with parameters: {'learning_rate': 0.05, 'max_depth': 9, 'n_estimators': 100}
# Accuracy: 0.7561396776669225
# Training with parameters: {'learning_rate': 0.05, 'max_depth': 9, 'n_estimators': 200}
# Accuracy: 0.7714888718342287
# Training with parameters: {'learning_rate': 0.05, 'max_depth': 9, 'n_estimators': 300}
# Accuracy: 0.7774366845740599
# Training with parameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Accuracy: 0.7532617037605526
# Training with parameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}
# Accuracy: 0.7762854950115119
# Training with parameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 300}
# Accuracy: 0.7853031465848043
# Training with parameters: {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 100}
# Accuracy: 0.7711051419800461
# Training with parameters: {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 200}
# Accuracy: 0.7805065234075211
# Training with parameters: {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 300}
# Accuracy: 0.7837682271680737
# Training with parameters: {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 100}
# Accuracy: 0.7697620874904068
# Training with parameters: {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 200}
# Accuracy: 0.7770529547198772
# Training with parameters: {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 300}
# Accuracy: 0.7806983883346125
#
# Best Parameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 300}
# Best Test Set Accuracy: 0.7853031465848043

# %%
from xgboost import XGBClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder

tfidf_vectorizer = TfidfVectorizer()
X_train = tfidf_vectorizer.fit_transform(train_df['text'])
X_test = tfidf_vectorizer.transform(test_df['text'])

label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(train_df['label'])
y_test = label_encoder.transform(test_df['label'])

# XGBoost
xgb_classifier = XGBClassifier(
    max_depth=6,
    n_estimators=200,
    learning_rate=0.05,
    random_state=42,
    use_label_encoder=False
)
xgb_classifier.fit(X_train, y_train)

y_test_pred = xgb_classifier.predict(X_test)

print("Test Set Evaluation:")
print(f"Accuracy: {accuracy_score(y_test, y_test_pred)}")
print(classification_report(y_test, y_test_pred))
# Out:
# Test Set Evaluation:
# Accuracy: 0.7674597083653109
#               precision    recall  f1-score   support
#
#            0       0.83      0.78      0.80       642
#            1       0.77      0.76      0.76       671
#            2       0.82      0.65      0.73       695
#            3       0.70      0.70      0.70       635
#            4       0.58      0.75      0.65       653
#            5       0.78      0.96      0.86       633
#            6       0.91      0.79      0.85       642
#            7       0.83      0.76      0.80       641
#
#     accuracy                           0.77      5212
#    macro avg       0.78      0.77      0.77      5212
# weighted avg       0.78      0.77      0.77      5212

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, accuracy_score
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from itertools import product

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
tokenizer = Tokenizer()
tokenizer.fit_on_texts(train_df['text'])

X_train = tokenizer.texts_to_sequences(train_df['text'])
X_test = tokenizer.texts_to_sequences(test_df['text'])
max_len = max(len(x) for x in X_train + X_test)

X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(train_df['label'])
y_test = label_encoder.transform(test_df['label'])

class TextDataset(Dataset):
    def __init__(self, texts, labels):
        self.texts = torch.tensor(texts, dtype=torch.long)
        self.labels = torch.tensor(labels, dtype=torch.long)

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        return self.texts[idx], self.labels[idx]

train_dataset = TextDataset(X_train, y_train)
test_dataset = TextDataset(X_test, y_test)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

class ThreeLayerLSTM(nn.Module):
    def __init__(self, vocab_size, embed_dim, lstm_units, output_dim, dropout_rate):
        super(ThreeLayerLSTM, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim)
        self.lstm1 = nn.LSTM(embed_dim, lstm_units, batch_first=True, dropout=dropout_rate, bidirectional=True)
        self.lstm2 = nn.LSTM(lstm_units * 2, lstm_units, batch_first=True, dropout=dropout_rate, bidirectional=True)
        self.lstm3 = nn.LSTM(lstm_units * 2, lstm_units, batch_first=True, dropout=dropout_rate, bidirectional=True)
        self.fc = nn.Linear(lstm_units * 2, output_dim)
        self.dropout = nn.Dropout(dropout_rate)

    def forward(self, x):
        x = self.embedding(x)
        x, _ = self.lstm1(x)
        x, _ = self.lstm2(x)
        x, _ = self.lstm3(x)
        x = self.dropout(x[:, -1, :])
        x = self.fc(x)
        return x

output_dim = len(np.unique(y_train))
param_grid = {
    'embed_dim': [50, 100],
    'lstm_units': [64, 100],
    'dropout_rate': [0.2, 0.3],
    'learning_rate': [0.001, 0.0005]
}

param_combinations = list(product(
    param_grid['embed_dim'],
    param_grid['lstm_units'],
    param_grid['dropout_rate'],
    param_grid['learning_rate']
))

results = []

# Грід серч
for embed_dim, lstm_units, dropout_rate, learning_rate in param_combinations:
    print(f"Training with parameters: embed_dim={embed_dim}, lstm_units={lstm_units}, dropout_rate={dropout_rate}, learning_rate={learning_rate}")

    model = ThreeLayerLSTM(len(tokenizer.word_index) + 1, embed_dim, lstm_units, output_dim, dropout_rate).to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    def train_model(model, train_loader, optimizer, criterion, device, epochs=50):
        model.train()
        history = {'loss': [], 'accuracy': []}
        for epoch in range(epochs):
            total_loss, correct = 0, 0
            for texts, labels in train_loader:
                texts, labels = texts.to(device), labels.to(device)

                optimizer.zero_grad()
                outputs = model(texts)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()

                total_loss += loss.item()
                correct += (outputs.argmax(1) == labels).sum().item()

            accuracy = correct / len(train_loader.dataset)
            history['loss'].append(total_loss / len(train_loader))
            history['accuracy'].append(accuracy)
            print(f"Epoch {epoch + 1}/{epochs}, Loss: {total_loss / len(train_loader):.4f}, Accuracy: {accuracy:.4f}")
        return history

    history = train_model(model, train_loader, optimizer, criterion, device)

    def evaluate_model(model, test_loader, device):
        model.eval()
        all_preds, all_labels = [], []
        with torch.no_grad():
            for texts, labels in test_loader:
                texts, labels = texts.to(device), labels.to(device)
                outputs = model(texts)
                preds = outputs.argmax(1).cpu().numpy()
                all_preds.extend(preds)
                all_labels.extend(labels.cpu().numpy())
        return all_preds, all_labels

    y_test_pred, y_test_labels = evaluate_model(model, test_loader, device)
    test_acc = accuracy_score(y_test_labels, y_test_pred)
    results.append({
        'embed_dim': embed_dim,
        'lstm_units': lstm_units,
        'dropout_rate': dropout_rate,
        'learning_rate': learning_rate,
        'train_loss': history['loss'][-1],
        'train_acc': history['accuracy'][-1],
        'test_acc': test_acc
    })

    print(f"Results: Train Loss: {history['loss'][-1]:.4f}, Train Accuracy: {history['accuracy'][-1]:.4f}, Test Accuracy: {test_acc:.4f}\n")

best_result = max(results, key=lambda x: x['test_acc'])
print("Best Parameters:", best_result)
# Out:
# Using device: cuda
# Training with parameters: embed_dim=50, lstm_units=64, dropout_rate=0.2, learning_rate=0.001
# Epoch 1/50, Loss: 1.9084, Accuracy: 0.2331
# Epoch 2/50, Loss: 1.6566, Accuracy: 0.3553
# Epoch 3/50, Loss: 1.5296, Accuracy: 0.4098
# Epoch 4/50, Loss: 1.3733, Accuracy: 0.4749
# Epoch 5/50, Loss: 1.2530, Accuracy: 0.5256
# Epoch 6/50, Loss: 1.1864, Accuracy: 0.5632
# Epoch 7/50, Loss: 1.0246, Accuracy: 0.6381
# Epoch 8/50, Loss: 0.8471, Accuracy: 0.7129
# Epoch 9/50, Loss: 0.7062, Accuracy: 0.7659
# Epoch 10/50, Loss: 0.6210, Accuracy: 0.7960
# Epoch 11/50, Loss: 0.5571, Accuracy: 0.8191
# Epoch 12/50, Loss: 0.4951, Accuracy: 0.8405
# Epoch 13/50, Loss: 0.4318, Accuracy: 0.8642
# Epoch 14/50, Loss: 0.3667, Accuracy: 0.8867
# Epoch 15/50, Loss: 0.3142, Accuracy: 0.9064
# Epoch 16/50, Loss: 0.2648, Accuracy: 0.9217
# Epoch 17/50, Loss: 0.2210, Accuracy: 0.9348
# Epoch 18/50, Loss: 0.1825, Accuracy: 0.9490
# Epoch 19/50, Loss: 0.1527, Accuracy: 0.9576
# Epoch 20/50, Loss: 0.1299, Accuracy: 0.9646
# Epoch 21/50, Loss: 0.1030, Accuracy: 0.9729
# Epoch 22/50, Loss: 0.0861, Accuracy: 0.9765
# Epoch 23/50, Loss: 0.0715, Accuracy: 0.9801
# Epoch 24/50, Loss: 0.0588, Accuracy: 0.9835
# Epoch 25/50, Loss: 0.0601, Accuracy: 0.9833
# Epoch 26/50, Loss: 0.0488, Accuracy: 0.9861
# Epoch 27/50, Loss: 0.0423, Accuracy: 0.9878
# Epoch 28/50, Loss: 0.0443, Accuracy: 0.9883
# Epoch 29/50, Loss: 0.0222, Accuracy: 0.9942
# Epoch 30/50, Loss: 0.0228, Accuracy: 0.9938
# Epoch 31/50, Loss: 0.0266, Accuracy: 0.9921
# Epoch 32/50, Loss: 0.0199, Accuracy: 0.9942
# Epoch 33/50, Loss: 0.0179, Accuracy: 0.9949
# Epoch 34/50, Loss: 0.0320, Accuracy: 0.9906
# Epoch 35/50, Loss: 0.0236, Accuracy: 0.9931
# Epoch 36/50, Loss: 0.0099, Accuracy: 0.9973
# Epoch 37/50, Loss: 0.0108, Accuracy: 0.9969
# Epoch 38/50, Loss: 0.0038, Accuracy: 0.9991
# Epoch 39/50, Loss: 0.0229, Accuracy: 0.9934
# Epoch 40/50, Loss: 0.0409, Accuracy: 0.9879
# Epoch 41/50, Loss: 0.0233, Accuracy: 0.9927
# Epoch 42/50, Loss: 0.0096, Accuracy: 0.9973
# Epoch 43/50, Loss: 0.0064, Accuracy: 0.9982
# Epoch 44/50, Loss: 0.0039, Accuracy: 0.9991
# Epoch 45/50, Loss: 0.0075, Accuracy: 0.9976
# Epoch 46/50, Loss: 0.0223, Accuracy: 0.9931
# Epoch 47/50, Loss: 0.0175, Accuracy: 0.9946
# Epoch 48/50, Loss: 0.0083, Accuracy: 0.9977
# Epoch 49/50, Loss: 0.0089, Accuracy: 0.9974
# Epoch 50/50, Loss: 0.0091, Accuracy: 0.9971
# Results: Train Loss: 0.0091, Train Accuracy: 0.9971, Test Accuracy: 0.7082
#
# Training with parameters: embed_dim=50, lstm_units=64, dropout_rate=0.2, learning_rate=0.0005
# Epoch 1/50, Loss: 1.9712, Accuracy: 0.1973
# Epoch 2/50, Loss: 1.7387, Accuracy: 0.3127
# Epoch 3/50, Loss: 1.5511, Accuracy: 0.4093
# Epoch 4/50, Loss: 1.4053, Accuracy: 0.4793
# Epoch 5/50, Loss: 1.2713, Accuracy: 0.5337
# Epoch 6/50, Loss: 1.2079, Accuracy: 0.5663
# Epoch 7/50, Loss: 1.1190, Accuracy: 0.6002
# Epoch 8/50, Loss: 1.0385, Accuracy: 0.6310
# Epoch 9/50, Loss: 0.9583, Accuracy: 0.6667
# Epoch 10/50, Loss: 0.8873, Accuracy: 0.6919
# Epoch 11/50, Loss: 0.8302, Accuracy: 0.7131
# Epoch 12/50, Loss: 0.7703, Accuracy: 0.7362
# Epoch 13/50, Loss: 0.7296, Accuracy: 0.7499
# Epoch 14/50, Loss: 0.6803, Accuracy: 0.7725
# Epoch 15/50, Loss: 0.6302, Accuracy: 0.7922
# Epoch 16/50, Loss: 0.5624, Accuracy: 0.8140
# Epoch 17/50, Loss: 0.5510, Accuracy: 0.8232
# Epoch 18/50, Loss: 0.4819, Accuracy: 0.8445
# Epoch 19/50, Loss: 0.4466, Accuracy: 0.8562
# Epoch 20/50, Loss: 0.3954, Accuracy: 0.8755
# Epoch 21/50, Loss: 0.3614, Accuracy: 0.8852
# Epoch 22/50, Loss: 0.3376, Accuracy: 0.8950
# Epoch 23/50, Loss: 0.3038, Accuracy: 0.9057
# Epoch 24/50, Loss: 0.2647, Accuracy: 0.9186
# Epoch 25/50, Loss: 0.2332, Accuracy: 0.9306
# Epoch 26/50, Loss: 0.2185, Accuracy: 0.9329
# Epoch 27/50, Loss: 0.1903, Accuracy: 0.9440
# Epoch 28/50, Loss: 0.1618, Accuracy: 0.9520
# Epoch 29/50, Loss: 0.1512, Accuracy: 0.9547
# Epoch 30/50, Loss: 0.1551, Accuracy: 0.9526
# Epoch 31/50, Loss: 0.1218, Accuracy: 0.9632
# Epoch 32/50, Loss: 0.1174, Accuracy: 0.9651
# Epoch 33/50, Loss: 0.1253, Accuracy: 0.9630
# Epoch 34/50, Loss: 0.0879, Accuracy: 0.9747
# Epoch 35/50, Loss: 0.1872, Accuracy: 0.9449
# Epoch 36/50, Loss: 0.0870, Accuracy: 0.9748
# Epoch 37/50, Loss: 0.0553, Accuracy: 0.9859
# Epoch 38/50, Loss: 0.0515, Accuracy: 0.9863
# Epoch 39/50, Loss: 0.0622, Accuracy: 0.9822
# Epoch 40/50, Loss: 0.0506, Accuracy: 0.9858
# Epoch 41/50, Loss: 0.0417, Accuracy: 0.9889
# Epoch 42/50, Loss: 0.0492, Accuracy: 0.9850
# Epoch 43/50, Loss: 0.0422, Accuracy: 0.9878
# Epoch 44/50, Loss: 0.0510, Accuracy: 0.9849
# Epoch 45/50, Loss: 0.0361, Accuracy: 0.9897
# Epoch 46/50, Loss: 0.0404, Accuracy: 0.9883
# Epoch 47/50, Loss: 0.0445, Accuracy: 0.9868
# Epoch 48/50, Loss: 0.0423, Accuracy: 0.9882
# Epoch 49/50, Loss: 0.0151, Accuracy: 0.9962
# Epoch 50/50, Loss: 0.0173, Accuracy: 0.9954
# Results: Train Loss: 0.0173, Train Accuracy: 0.9954, Test Accuracy: 0.7122
#
# Training with parameters: embed_dim=50, lstm_units=64, dropout_rate=0.3, learning_rate=0.001
# Epoch 1/50, Loss: 1.8824, Accuracy: 0.2475
# Epoch 2/50, Loss: 1.6063, Accuracy: 0.3642
# Epoch 3/50, Loss: 1.5345, Accuracy: 0.4032
# Epoch 4/50, Loss: 1.4718, Accuracy: 0.4334
# Epoch 5/50, Loss: 1.3162, Accuracy: 0.5012
# Epoch 6/50, Loss: 1.1684, Accuracy: 0.5771
# Epoch 7/50, Loss: 0.9918, Accuracy: 0.6584
# Epoch 8/50, Loss: 1.0367, Accuracy: 0.6509
# Epoch 9/50, Loss: 0.8199, Accuracy: 0.7294
# Epoch 10/50, Loss: 0.6942, Accuracy: 0.7762
# Epoch 11/50, Loss: 0.6807, Accuracy: 0.7795
# Epoch 12/50, Loss: 0.5645, Accuracy: 0.8183
# Epoch 13/50, Loss: 0.5852, Accuracy: 0.8178
# Epoch 14/50, Loss: 0.5210, Accuracy: 0.8356
# Epoch 15/50, Loss: 0.4253, Accuracy: 0.8703
# Epoch 16/50, Loss: 0.3726, Accuracy: 0.8875
# Epoch 17/50, Loss: 0.3196, Accuracy: 0.9051
# Epoch 18/50, Loss: 0.2716, Accuracy: 0.9210
# Epoch 19/50, Loss: 0.2256, Accuracy: 0.9372
# Epoch 20/50, Loss: 0.2010, Accuracy: 0.9422
# Epoch 21/50, Loss: 0.1758, Accuracy: 0.9518
# Epoch 22/50, Loss: 0.1295, Accuracy: 0.9655
# Epoch 23/50, Loss: 0.1053, Accuracy: 0.9719
# Epoch 24/50, Loss: 0.0949, Accuracy: 0.9755
# Epoch 25/50, Loss: 0.0761, Accuracy: 0.9787
# Epoch 26/50, Loss: 0.0741, Accuracy: 0.9788
# Epoch 27/50, Loss: 0.0642, Accuracy: 0.9829
# Epoch 28/50, Loss: 0.0548, Accuracy: 0.9851
# Epoch 29/50, Loss: 0.0366, Accuracy: 0.9909
# Epoch 30/50, Loss: 0.0206, Accuracy: 0.9957
# Epoch 31/50, Loss: 0.0356, Accuracy: 0.9896
# Epoch 32/50, Loss: 0.0301, Accuracy: 0.9914
# Epoch 33/50, Loss: 0.0380, Accuracy: 0.9889
# Epoch 34/50, Loss: 0.0253, Accuracy: 0.9928
# Epoch 35/50, Loss: 0.0165, Accuracy: 0.9945
# Epoch 36/50, Loss: 0.0167, Accuracy: 0.9958
# Epoch 37/50, Loss: 0.0148, Accuracy: 0.9961
# Epoch 38/50, Loss: 0.0137, Accuracy: 0.9960
# Epoch 39/50, Loss: 0.0247, Accuracy: 0.9924
# Epoch 40/50, Loss: 0.0353, Accuracy: 0.9890
# Epoch 41/50, Loss: 0.0178, Accuracy: 0.9940
# Epoch 42/50, Loss: 0.0082, Accuracy: 0.9974
# Epoch 43/50, Loss: 0.0023, Accuracy: 0.9994
# Epoch 44/50, Loss: 0.0016, Accuracy: 0.9998
# Epoch 45/50, Loss: 0.0011, Accuracy: 0.9997
# Epoch 46/50, Loss: 0.0012, Accuracy: 0.9998
# Epoch 47/50, Loss: 0.0010, Accuracy: 0.9998
# Epoch 48/50, Loss: 0.0010, Accuracy: 0.9998
# Epoch 49/50, Loss: 0.0008, Accuracy: 0.9999
# Epoch 50/50, Loss: 0.0007, Accuracy: 0.9999
# Results: Train Loss: 0.0007, Train Accuracy: 0.9999, Test Accuracy: 0.7268
#
# Training with parameters: embed_dim=50, lstm_units=64, dropout_rate=0.3, learning_rate=0.0005
# Epoch 1/50, Loss: 1.9665, Accuracy: 0.2044
# Epoch 2/50, Loss: 1.7093, Accuracy: 0.3394
# Epoch 3/50, Loss: 1.5313, Accuracy: 0.4213
# Epoch 4/50, Loss: 1.4056, Accuracy: 0.4822
# Epoch 5/50, Loss: 1.2869, Accuracy: 0.5439
# Epoch 6/50, Loss: 1.2250, Accuracy: 0.5774
# Epoch 7/50, Loss: 1.1585, Accuracy: 0.6033
# Epoch 8/50, Loss: 1.0613, Accuracy: 0.6380
# Epoch 9/50, Loss: 0.9594, Accuracy: 0.6817
# Epoch 10/50, Loss: 0.8622, Accuracy: 0.7159
# Epoch 11/50, Loss: 0.8096, Accuracy: 0.7363
# Epoch 12/50, Loss: 0.7812, Accuracy: 0.7454
# Epoch 13/50, Loss: 0.7062, Accuracy: 0.7731
# Epoch 14/50, Loss: 0.6700, Accuracy: 0.7833
# Epoch 15/50, Loss: 0.6246, Accuracy: 0.7998
# Epoch 16/50, Loss: 0.5808, Accuracy: 0.8159
# Epoch 17/50, Loss: 0.5342, Accuracy: 0.8318
# Epoch 18/50, Loss: 0.4999, Accuracy: 0.8438
# Epoch 19/50, Loss: 0.4932, Accuracy: 0.8472
# Epoch 20/50, Loss: 0.4486, Accuracy: 0.8591
# Epoch 21/50, Loss: 0.4061, Accuracy: 0.8752
# Epoch 22/50, Loss: 0.3712, Accuracy: 0.8857
# Epoch 23/50, Loss: 0.3361, Accuracy: 0.8976
# Epoch 24/50, Loss: 0.3128, Accuracy: 0.9055
# Epoch 25/50, Loss: 0.2865, Accuracy: 0.9155
# Epoch 26/50, Loss: 0.2539, Accuracy: 0.9256
# Epoch 27/50, Loss: 0.2350, Accuracy: 0.9320
# Epoch 28/50, Loss: 0.2209, Accuracy: 0.9353
# Epoch 29/50, Loss: 0.2110, Accuracy: 0.9381
# Epoch 30/50, Loss: 0.1824, Accuracy: 0.9493
# Epoch 31/50, Loss: 0.1611, Accuracy: 0.9548
# Epoch 32/50, Loss: 0.1419, Accuracy: 0.9595
# Epoch 33/50, Loss: 0.1345, Accuracy: 0.9623
# Epoch 34/50, Loss: 0.1487, Accuracy: 0.9577
# Epoch 35/50, Loss: 0.1266, Accuracy: 0.9643
# Epoch 36/50, Loss: 0.0943, Accuracy: 0.9749
# Epoch 37/50, Loss: 0.0815, Accuracy: 0.9794
# Epoch 38/50, Loss: 0.1155, Accuracy: 0.9677
# Epoch 39/50, Loss: 0.1000, Accuracy: 0.9735
# Epoch 40/50, Loss: 0.0764, Accuracy: 0.9789
# Epoch 41/50, Loss: 0.0764, Accuracy: 0.9794
# Epoch 42/50, Loss: 0.0567, Accuracy: 0.9851
# Epoch 43/50, Loss: 0.0552, Accuracy: 0.9858
# Epoch 44/50, Loss: 0.0488, Accuracy: 0.9876
# Epoch 45/50, Loss: 0.0553, Accuracy: 0.9842
# Epoch 46/50, Loss: 0.0534, Accuracy: 0.9846
# Epoch 47/50, Loss: 0.0487, Accuracy: 0.9870
# Epoch 48/50, Loss: 0.0543, Accuracy: 0.9841
# Epoch 49/50, Loss: 0.0396, Accuracy: 0.9893
# Epoch 50/50, Loss: 0.0406, Accuracy: 0.9884
# Results: Train Loss: 0.0406, Train Accuracy: 0.9884, Test Accuracy: 0.7182
#
# Training with parameters: embed_dim=50, lstm_units=100, dropout_rate=0.2, learning_rate=0.001
# Epoch 1/50, Loss: 1.9071, Accuracy: 0.2376
# Epoch 2/50, Loss: 1.8611, Accuracy: 0.2841
# Epoch 3/50, Loss: 1.6300, Accuracy: 0.3630
# Epoch 4/50, Loss: 1.6606, Accuracy: 0.3504
# Epoch 5/50, Loss: 1.5392, Accuracy: 0.4058
# Epoch 6/50, Loss: 1.3398, Accuracy: 0.4908
# Epoch 7/50, Loss: 1.2229, Accuracy: 0.5394
# Epoch 8/50, Loss: 1.1484, Accuracy: 0.5723
# Epoch 9/50, Loss: 0.9985, Accuracy: 0.6368
# Epoch 10/50, Loss: 0.8690, Accuracy: 0.6945
# Epoch 11/50, Loss: 0.7561, Accuracy: 0.7410
# Epoch 12/50, Loss: 0.6657, Accuracy: 0.7759
# Epoch 13/50, Loss: 0.5673, Accuracy: 0.8136
# Epoch 14/50, Loss: 0.4912, Accuracy: 0.8406
# Epoch 15/50, Loss: 0.4270, Accuracy: 0.8606
# Epoch 16/50, Loss: 0.3803, Accuracy: 0.8786
# Epoch 17/50, Loss: 0.3179, Accuracy: 0.9003
# Epoch 18/50, Loss: 0.2600, Accuracy: 0.9209
# Epoch 19/50, Loss: 0.2313, Accuracy: 0.9282
# Epoch 20/50, Loss: 0.1862, Accuracy: 0.9432
# Epoch 21/50, Loss: 0.1508, Accuracy: 0.9557
# Epoch 22/50, Loss: 0.1188, Accuracy: 0.9649
# Epoch 23/50, Loss: 0.0990, Accuracy: 0.9726
# Epoch 24/50, Loss: 0.0857, Accuracy: 0.9741
# Epoch 25/50, Loss: 0.0856, Accuracy: 0.9745
# Epoch 26/50, Loss: 0.0564, Accuracy: 0.9833
# Epoch 27/50, Loss: 0.0546, Accuracy: 0.9835
# Epoch 28/50, Loss: 0.0512, Accuracy: 0.9830
# Epoch 29/50, Loss: 0.0432, Accuracy: 0.9872
# Epoch 30/50, Loss: 0.0325, Accuracy: 0.9905
# Epoch 31/50, Loss: 0.0327, Accuracy: 0.9904
# Epoch 32/50, Loss: 0.0203, Accuracy: 0.9947
# Epoch 33/50, Loss: 0.0299, Accuracy: 0.9898
# Epoch 34/50, Loss: 0.0306, Accuracy: 0.9905
# Epoch 35/50, Loss: 0.0243, Accuracy: 0.9925
# Epoch 36/50, Loss: 0.0205, Accuracy: 0.9938
# Epoch 37/50, Loss: 0.0166, Accuracy: 0.9947
# Epoch 38/50, Loss: 0.0279, Accuracy: 0.9912
# Epoch 39/50, Loss: 0.0267, Accuracy: 0.9923
# Epoch 40/50, Loss: 0.0145, Accuracy: 0.9957
# Epoch 41/50, Loss: 0.0074, Accuracy: 0.9979
# Epoch 42/50, Loss: 0.0150, Accuracy: 0.9956
# Epoch 43/50, Loss: 0.0147, Accuracy: 0.9962
# Epoch 44/50, Loss: 0.0218, Accuracy: 0.9939
# Epoch 45/50, Loss: 0.0217, Accuracy: 0.9933
# Epoch 46/50, Loss: 0.0131, Accuracy: 0.9963
# Epoch 47/50, Loss: 0.0074, Accuracy: 0.9980
# Epoch 48/50, Loss: 0.0056, Accuracy: 0.9985
# Epoch 49/50, Loss: 0.0197, Accuracy: 0.9944
# Epoch 50/50, Loss: 0.0204, Accuracy: 0.9935
# Results: Train Loss: 0.0204, Train Accuracy: 0.9935, Test Accuracy: 0.7276
#
# Training with parameters: embed_dim=50, lstm_units=100, dropout_rate=0.2, learning_rate=0.0005
# Epoch 1/50, Loss: 1.9679, Accuracy: 0.2003
# Epoch 2/50, Loss: 1.7609, Accuracy: 0.3007
# Epoch 3/50, Loss: 1.5558, Accuracy: 0.4102
# Epoch 4/50, Loss: 1.3932, Accuracy: 0.4698
# Epoch 5/50, Loss: 1.2490, Accuracy: 0.5201
# Epoch 6/50, Loss: 1.1596, Accuracy: 0.5615
# Epoch 7/50, Loss: 1.0694, Accuracy: 0.6102
# Epoch 8/50, Loss: 0.9106, Accuracy: 0.6875
# Epoch 9/50, Loss: 0.7829, Accuracy: 0.7365
# Epoch 10/50, Loss: 0.6975, Accuracy: 0.7690
# Epoch 11/50, Loss: 0.6304, Accuracy: 0.7925
# Epoch 12/50, Loss: 0.5848, Accuracy: 0.8064
# Epoch 13/50, Loss: 0.5283, Accuracy: 0.8305
# Epoch 14/50, Loss: 0.4776, Accuracy: 0.8452
# Epoch 15/50, Loss: 0.4345, Accuracy: 0.8600
# Epoch 16/50, Loss: 0.3863, Accuracy: 0.8787
# Epoch 17/50, Loss: 0.3446, Accuracy: 0.8927
# Epoch 18/50, Loss: 0.3065, Accuracy: 0.9056
# Epoch 19/50, Loss: 0.2586, Accuracy: 0.9216
# Epoch 20/50, Loss: 0.2326, Accuracy: 0.9307
# Epoch 21/50, Loss: 0.2034, Accuracy: 0.9403
# Epoch 22/50, Loss: 0.1784, Accuracy: 0.9462
# Epoch 23/50, Loss: 0.1566, Accuracy: 0.9535
# Epoch 24/50, Loss: 0.1430, Accuracy: 0.9566
# Epoch 25/50, Loss: 0.1033, Accuracy: 0.9702
# Epoch 26/50, Loss: 0.0972, Accuracy: 0.9719
# Epoch 27/50, Loss: 0.0969, Accuracy: 0.9713
# Epoch 28/50, Loss: 0.0688, Accuracy: 0.9806
# Epoch 29/50, Loss: 0.0636, Accuracy: 0.9823
# Epoch 30/50, Loss: 0.0597, Accuracy: 0.9822
# Epoch 31/50, Loss: 0.0575, Accuracy: 0.9831
# Epoch 32/50, Loss: 0.0584, Accuracy: 0.9827
# Epoch 33/50, Loss: 0.0421, Accuracy: 0.9882
# Epoch 34/50, Loss: 0.0448, Accuracy: 0.9877
# Epoch 35/50, Loss: 0.0450, Accuracy: 0.9860
# Epoch 36/50, Loss: 0.0379, Accuracy: 0.9891
# Epoch 37/50, Loss: 0.0181, Accuracy: 0.9961
# Epoch 38/50, Loss: 0.0407, Accuracy: 0.9876
# Epoch 39/50, Loss: 0.0600, Accuracy: 0.9820
# Epoch 40/50, Loss: 0.0301, Accuracy: 0.9905
# Epoch 41/50, Loss: 0.0172, Accuracy: 0.9960
# Epoch 42/50, Loss: 0.0186, Accuracy: 0.9950
# Epoch 43/50, Loss: 0.0219, Accuracy: 0.9936
# Epoch 44/50, Loss: 0.0254, Accuracy: 0.9924
# Epoch 45/50, Loss: 0.0346, Accuracy: 0.9892
# Epoch 46/50, Loss: 0.0132, Accuracy: 0.9963
# Epoch 47/50, Loss: 0.0043, Accuracy: 0.9991
# Epoch 48/50, Loss: 0.0024, Accuracy: 0.9995
# Epoch 49/50, Loss: 0.0016, Accuracy: 0.9997
# Epoch 50/50, Loss: 0.0020, Accuracy: 0.9996
# Results: Train Loss: 0.0020, Train Accuracy: 0.9996, Test Accuracy: 0.7222
#
# Training with parameters: embed_dim=50, lstm_units=100, dropout_rate=0.3, learning_rate=0.001
# Epoch 1/50, Loss: 1.8943, Accuracy: 0.2434
# Epoch 2/50, Loss: 1.5524, Accuracy: 0.3952
# Epoch 3/50, Loss: 1.2833, Accuracy: 0.5121
# Epoch 4/50, Loss: 1.1391, Accuracy: 0.5777
# Epoch 5/50, Loss: 0.9427, Accuracy: 0.6777
# Epoch 6/50, Loss: 0.7647, Accuracy: 0.7431
# Epoch 7/50, Loss: 0.6633, Accuracy: 0.7799
# Epoch 8/50, Loss: 0.5757, Accuracy: 0.8099
# Epoch 9/50, Loss: 0.5133, Accuracy: 0.8346
# Epoch 10/50, Loss: 0.4452, Accuracy: 0.8559
# Epoch 11/50, Loss: 0.3771, Accuracy: 0.8839
# Epoch 12/50, Loss: 0.3201, Accuracy: 0.9015
# Epoch 13/50, Loss: 0.2615, Accuracy: 0.9193
# Epoch 14/50, Loss: 0.2201, Accuracy: 0.9335
# Epoch 15/50, Loss: 0.1758, Accuracy: 0.9476
# Epoch 16/50, Loss: 0.1470, Accuracy: 0.9574
# Epoch 17/50, Loss: 0.1138, Accuracy: 0.9668
# Epoch 18/50, Loss: 0.0997, Accuracy: 0.9709
# Epoch 19/50, Loss: 0.0880, Accuracy: 0.9742
# Epoch 20/50, Loss: 0.0791, Accuracy: 0.9769
# Epoch 21/50, Loss: 0.0540, Accuracy: 0.9852
# Epoch 22/50, Loss: 0.0515, Accuracy: 0.9858
# Epoch 23/50, Loss: 0.0529, Accuracy: 0.9853
# Epoch 24/50, Loss: 0.0548, Accuracy: 0.9838
# Epoch 25/50, Loss: 0.0345, Accuracy: 0.9900
# Epoch 26/50, Loss: 0.0428, Accuracy: 0.9869
# Epoch 27/50, Loss: 0.0281, Accuracy: 0.9926
# Epoch 28/50, Loss: 0.0355, Accuracy: 0.9901
# Epoch 29/50, Loss: 0.0314, Accuracy: 0.9908
# Epoch 30/50, Loss: 0.0209, Accuracy: 0.9939
# Epoch 31/50, Loss: 0.0155, Accuracy: 0.9955
# Epoch 32/50, Loss: 0.0231, Accuracy: 0.9931
# Epoch 33/50, Loss: 0.0194, Accuracy: 0.9950
# Epoch 34/50, Loss: 0.0244, Accuracy: 0.9925
# Epoch 35/50, Loss: 0.0253, Accuracy: 0.9921
# Epoch 36/50, Loss: 0.0230, Accuracy: 0.9938
# Epoch 37/50, Loss: 0.0103, Accuracy: 0.9971
# Epoch 38/50, Loss: 0.0168, Accuracy: 0.9956
# Epoch 39/50, Loss: 0.0159, Accuracy: 0.9959
# Epoch 40/50, Loss: 0.0199, Accuracy: 0.9938
# Epoch 41/50, Loss: 0.0120, Accuracy: 0.9964
# Epoch 42/50, Loss: 0.0228, Accuracy: 0.9934
# Epoch 43/50, Loss: 0.0190, Accuracy: 0.9945
# Epoch 44/50, Loss: 0.0125, Accuracy: 0.9965
# Epoch 45/50, Loss: 0.0100, Accuracy: 0.9972
# Epoch 46/50, Loss: 0.0169, Accuracy: 0.9953
# Epoch 47/50, Loss: 0.0170, Accuracy: 0.9951
# Epoch 48/50, Loss: 0.0042, Accuracy: 0.9988
# Epoch 49/50, Loss: 0.0022, Accuracy: 0.9995
# Epoch 50/50, Loss: 0.0015, Accuracy: 0.9997
# Results: Train Loss: 0.0015, Train Accuracy: 0.9997, Test Accuracy: 0.7389
#
# Training with parameters: embed_dim=50, lstm_units=100, dropout_rate=0.3, learning_rate=0.0005
# Epoch 1/50, Loss: 1.9475, Accuracy: 0.2105
# Epoch 2/50, Loss: 1.8245, Accuracy: 0.2791
# Epoch 3/50, Loss: 1.6772, Accuracy: 0.3316
# Epoch 4/50, Loss: 1.6767, Accuracy: 0.3421
# Epoch 5/50, Loss: 1.5595, Accuracy: 0.3939
# Epoch 6/50, Loss: 1.4329, Accuracy: 0.4545
# Epoch 7/50, Loss: 1.3336, Accuracy: 0.4929
# Epoch 8/50, Loss: 1.2905, Accuracy: 0.5105
# Epoch 9/50, Loss: 1.2249, Accuracy: 0.5340
# Epoch 10/50, Loss: 1.1806, Accuracy: 0.5457
# Epoch 11/50, Loss: 1.1417, Accuracy: 0.5637
# Epoch 12/50, Loss: 1.1903, Accuracy: 0.5469
# Epoch 13/50, Loss: 1.0901, Accuracy: 0.5923
# Epoch 14/50, Loss: 1.0034, Accuracy: 0.6340
# Epoch 15/50, Loss: 0.9254, Accuracy: 0.6716
# Epoch 16/50, Loss: 0.8720, Accuracy: 0.6999
# Epoch 17/50, Loss: 0.8437, Accuracy: 0.7115
# Epoch 18/50, Loss: 0.7593, Accuracy: 0.7461
# Epoch 19/50, Loss: 0.8133, Accuracy: 0.7245
# Epoch 20/50, Loss: 0.6749, Accuracy: 0.7756
# Epoch 21/50, Loss: 0.6189, Accuracy: 0.7956
# Epoch 22/50, Loss: 0.5717, Accuracy: 0.8149
# Epoch 23/50, Loss: 0.5355, Accuracy: 0.8289
# Epoch 24/50, Loss: 0.5262, Accuracy: 0.8295
# Epoch 25/50, Loss: 0.4979, Accuracy: 0.8404
# Epoch 26/50, Loss: 0.4621, Accuracy: 0.8559
# Epoch 27/50, Loss: 0.4028, Accuracy: 0.8758
# Epoch 28/50, Loss: 0.4027, Accuracy: 0.8740
# Epoch 29/50, Loss: 0.3451, Accuracy: 0.8969
# Epoch 30/50, Loss: 0.3228, Accuracy: 0.9038
# Epoch 31/50, Loss: 0.2927, Accuracy: 0.9135
# Epoch 32/50, Loss: 0.2630, Accuracy: 0.9219
# Epoch 33/50, Loss: 0.2600, Accuracy: 0.9222
# Epoch 34/50, Loss: 0.2582, Accuracy: 0.9244
# Epoch 35/50, Loss: 0.2128, Accuracy: 0.9400
# Epoch 36/50, Loss: 0.1890, Accuracy: 0.9471
# Epoch 37/50, Loss: 0.1698, Accuracy: 0.9516
# Epoch 38/50, Loss: 0.1558, Accuracy: 0.9570
# Epoch 39/50, Loss: 0.1388, Accuracy: 0.9619
# Epoch 40/50, Loss: 0.1414, Accuracy: 0.9594
# Epoch 41/50, Loss: 0.1107, Accuracy: 0.9689
# Epoch 42/50, Loss: 0.1089, Accuracy: 0.9696
# Epoch 43/50, Loss: 0.0885, Accuracy: 0.9764
# Epoch 44/50, Loss: 0.0726, Accuracy: 0.9806
# Epoch 45/50, Loss: 0.0781, Accuracy: 0.9778
# Epoch 46/50, Loss: 0.0730, Accuracy: 0.9785
# Epoch 47/50, Loss: 0.0735, Accuracy: 0.9791
# Epoch 48/50, Loss: 0.0646, Accuracy: 0.9818
# Epoch 49/50, Loss: 0.0411, Accuracy: 0.9888
# Epoch 50/50, Loss: 0.0593, Accuracy: 0.9825
# Results: Train Loss: 0.0593, Train Accuracy: 0.9825, Test Accuracy: 0.7260
#
# Training with parameters: embed_dim=100, lstm_units=64, dropout_rate=0.2, learning_rate=0.001
# Epoch 1/50, Loss: 1.8860, Accuracy: 0.2358
# Epoch 2/50, Loss: 1.6025, Accuracy: 0.3757
# Epoch 3/50, Loss: 1.3588, Accuracy: 0.4810
# Epoch 4/50, Loss: 1.1956, Accuracy: 0.5508
# Epoch 5/50, Loss: 0.9639, Accuracy: 0.6643
# Epoch 6/50, Loss: 0.7191, Accuracy: 0.7654
# Epoch 7/50, Loss: 0.5919, Accuracy: 0.8127
# Epoch 8/50, Loss: 0.5048, Accuracy: 0.8426
# Epoch 9/50, Loss: 0.4185, Accuracy: 0.8710
# Epoch 10/50, Loss: 0.3449, Accuracy: 0.8960
# Epoch 11/50, Loss: 0.2743, Accuracy: 0.9196
# Epoch 12/50, Loss: 0.2180, Accuracy: 0.9388
# Epoch 13/50, Loss: 0.1755, Accuracy: 0.9517
# Epoch 14/50, Loss: 0.1585, Accuracy: 0.9551
# Epoch 15/50, Loss: 0.1202, Accuracy: 0.9672
# Epoch 16/50, Loss: 0.1019, Accuracy: 0.9719
# Epoch 17/50, Loss: 0.0850, Accuracy: 0.9775
# Epoch 18/50, Loss: 0.0738, Accuracy: 0.9791
# Epoch 19/50, Loss: 0.0718, Accuracy: 0.9806
# Epoch 20/50, Loss: 0.0504, Accuracy: 0.9868
# Epoch 21/50, Loss: 0.0465, Accuracy: 0.9880
# Epoch 22/50, Loss: 0.0478, Accuracy: 0.9864
# Epoch 23/50, Loss: 0.0375, Accuracy: 0.9897
# Epoch 24/50, Loss: 0.0431, Accuracy: 0.9876
# Epoch 25/50, Loss: 0.0451, Accuracy: 0.9863
# Epoch 26/50, Loss: 0.0295, Accuracy: 0.9917
# Epoch 27/50, Loss: 0.0309, Accuracy: 0.9910
# Epoch 28/50, Loss: 0.0191, Accuracy: 0.9946
# Epoch 29/50, Loss: 0.0167, Accuracy: 0.9953
# Epoch 30/50, Loss: 0.0230, Accuracy: 0.9941
# Epoch 31/50, Loss: 0.0258, Accuracy: 0.9927
# Epoch 32/50, Loss: 0.0363, Accuracy: 0.9887
# Epoch 33/50, Loss: 0.0184, Accuracy: 0.9943
# Epoch 34/50, Loss: 0.0122, Accuracy: 0.9970
# Epoch 35/50, Loss: 0.0088, Accuracy: 0.9980
# Epoch 36/50, Loss: 0.0257, Accuracy: 0.9920
# Epoch 37/50, Loss: 0.0205, Accuracy: 0.9942
# Epoch 38/50, Loss: 0.0129, Accuracy: 0.9959
# Epoch 39/50, Loss: 0.0264, Accuracy: 0.9930
# Epoch 40/50, Loss: 0.0184, Accuracy: 0.9943
# Epoch 41/50, Loss: 0.0073, Accuracy: 0.9982
# Epoch 42/50, Loss: 0.0092, Accuracy: 0.9973
# Epoch 43/50, Loss: 0.0161, Accuracy: 0.9953
# Epoch 44/50, Loss: 0.0123, Accuracy: 0.9966
# Epoch 45/50, Loss: 0.0109, Accuracy: 0.9966
# Epoch 46/50, Loss: 0.0116, Accuracy: 0.9968
# Epoch 47/50, Loss: 0.0127, Accuracy: 0.9964
# Epoch 48/50, Loss: 0.0074, Accuracy: 0.9980
# Epoch 49/50, Loss: 0.0044, Accuracy: 0.9988
# Epoch 50/50, Loss: 0.0179, Accuracy: 0.9949
# Results: Train Loss: 0.0179, Train Accuracy: 0.9949, Test Accuracy: 0.7314
#
# Training with parameters: embed_dim=100, lstm_units=64, dropout_rate=0.2, learning_rate=0.0005
# Epoch 1/50, Loss: 1.9189, Accuracy: 0.2215
# Epoch 2/50, Loss: 1.7270, Accuracy: 0.3195
# Epoch 3/50, Loss: 1.5070, Accuracy: 0.4146
# Epoch 4/50, Loss: 1.3929, Accuracy: 0.4700
# Epoch 5/50, Loss: 1.2623, Accuracy: 0.5285
# Epoch 6/50, Loss: 1.1652, Accuracy: 0.5694
# Epoch 7/50, Loss: 1.1100, Accuracy: 0.5946
# Epoch 8/50, Loss: 0.9364, Accuracy: 0.6654
# Epoch 9/50, Loss: 0.8453, Accuracy: 0.7036
# Epoch 10/50, Loss: 0.7582, Accuracy: 0.7424
# Epoch 11/50, Loss: 0.6776, Accuracy: 0.7741
# Epoch 12/50, Loss: 0.6014, Accuracy: 0.8014
# Epoch 13/50, Loss: 0.5692, Accuracy: 0.8116
# Epoch 14/50, Loss: 0.4952, Accuracy: 0.8414
# Epoch 15/50, Loss: 0.4232, Accuracy: 0.8671
# Epoch 16/50, Loss: 0.3762, Accuracy: 0.8826
# Epoch 17/50, Loss: 0.3307, Accuracy: 0.8986
# Epoch 18/50, Loss: 0.2858, Accuracy: 0.9125
# Epoch 19/50, Loss: 0.2420, Accuracy: 0.9292
# Epoch 20/50, Loss: 0.2321, Accuracy: 0.9298
# Epoch 21/50, Loss: 0.2122, Accuracy: 0.9373
# Epoch 22/50, Loss: 0.1593, Accuracy: 0.9545
# Epoch 23/50, Loss: 0.1191, Accuracy: 0.9671
# Epoch 24/50, Loss: 0.1109, Accuracy: 0.9705
# Epoch 25/50, Loss: 0.0943, Accuracy: 0.9730
# Epoch 26/50, Loss: 0.0859, Accuracy: 0.9760
# Epoch 27/50, Loss: 0.0813, Accuracy: 0.9776
# Epoch 28/50, Loss: 0.0676, Accuracy: 0.9812
# Epoch 29/50, Loss: 0.0526, Accuracy: 0.9858
# Epoch 30/50, Loss: 0.0480, Accuracy: 0.9875
# Epoch 31/50, Loss: 0.0581, Accuracy: 0.9845
# Epoch 32/50, Loss: 0.0636, Accuracy: 0.9815
# Epoch 33/50, Loss: 0.0402, Accuracy: 0.9891
# Epoch 34/50, Loss: 0.0480, Accuracy: 0.9873
# Epoch 35/50, Loss: 0.0390, Accuracy: 0.9897
# Epoch 36/50, Loss: 0.0343, Accuracy: 0.9909
# Epoch 37/50, Loss: 0.0216, Accuracy: 0.9949
# Epoch 38/50, Loss: 0.0317, Accuracy: 0.9909
# Epoch 39/50, Loss: 0.0164, Accuracy: 0.9960
# Epoch 40/50, Loss: 0.0149, Accuracy: 0.9964
# Epoch 41/50, Loss: 0.0230, Accuracy: 0.9932
# Epoch 42/50, Loss: 0.0331, Accuracy: 0.9895
# Epoch 43/50, Loss: 0.0293, Accuracy: 0.9914
# Epoch 44/50, Loss: 0.0361, Accuracy: 0.9888
# Epoch 45/50, Loss: 0.0181, Accuracy: 0.9950
# Epoch 46/50, Loss: 0.0083, Accuracy: 0.9979
# Epoch 47/50, Loss: 0.0062, Accuracy: 0.9981
# Epoch 48/50, Loss: 0.0155, Accuracy: 0.9953
# Epoch 49/50, Loss: 0.0193, Accuracy: 0.9941
# Epoch 50/50, Loss: 0.0233, Accuracy: 0.9932
# Results: Train Loss: 0.0233, Train Accuracy: 0.9932, Test Accuracy: 0.7078
#
# Training with parameters: embed_dim=100, lstm_units=64, dropout_rate=0.3, learning_rate=0.001
# Epoch 1/50, Loss: 1.8420, Accuracy: 0.2540
# Epoch 2/50, Loss: 1.5058, Accuracy: 0.4250
# Epoch 3/50, Loss: 1.3403, Accuracy: 0.5010
# Epoch 4/50, Loss: 1.2310, Accuracy: 0.5286
# Epoch 5/50, Loss: 1.0402, Accuracy: 0.6154
# Epoch 6/50, Loss: 0.8513, Accuracy: 0.7061
# Epoch 7/50, Loss: 0.6869, Accuracy: 0.7720
# Epoch 8/50, Loss: 0.5641, Accuracy: 0.8185
# Epoch 9/50, Loss: 0.4777, Accuracy: 0.8482
# Epoch 10/50, Loss: 0.3898, Accuracy: 0.8779
# Epoch 11/50, Loss: 0.3314, Accuracy: 0.8966
# Epoch 12/50, Loss: 0.2615, Accuracy: 0.9214
# Epoch 13/50, Loss: 0.2174, Accuracy: 0.9358
# Epoch 14/50, Loss: 0.1742, Accuracy: 0.9494
# Epoch 15/50, Loss: 0.1371, Accuracy: 0.9593
# Epoch 16/50, Loss: 0.1069, Accuracy: 0.9693
# Epoch 17/50, Loss: 0.0917, Accuracy: 0.9734
# Epoch 18/50, Loss: 0.0870, Accuracy: 0.9737
# Epoch 19/50, Loss: 0.0591, Accuracy: 0.9841
# Epoch 20/50, Loss: 0.0505, Accuracy: 0.9852
# Epoch 21/50, Loss: 0.0599, Accuracy: 0.9824
# Epoch 22/50, Loss: 0.0475, Accuracy: 0.9864
# Epoch 23/50, Loss: 0.0343, Accuracy: 0.9903
# Epoch 24/50, Loss: 0.0331, Accuracy: 0.9906
# Epoch 25/50, Loss: 0.0250, Accuracy: 0.9929
# Epoch 26/50, Loss: 0.0292, Accuracy: 0.9909
# Epoch 27/50, Loss: 0.0334, Accuracy: 0.9900
# Epoch 28/50, Loss: 0.0206, Accuracy: 0.9947
# Epoch 29/50, Loss: 0.0280, Accuracy: 0.9918
# Epoch 30/50, Loss: 0.0279, Accuracy: 0.9912
# Epoch 31/50, Loss: 0.0219, Accuracy: 0.9934
# Epoch 32/50, Loss: 0.0157, Accuracy: 0.9955
# Epoch 33/50, Loss: 0.0187, Accuracy: 0.9947
# Epoch 34/50, Loss: 0.0243, Accuracy: 0.9924
# Epoch 35/50, Loss: 0.0252, Accuracy: 0.9929
# Epoch 36/50, Loss: 0.0147, Accuracy: 0.9957
# Epoch 37/50, Loss: 0.0117, Accuracy: 0.9964
# Epoch 38/50, Loss: 0.0091, Accuracy: 0.9971
# Epoch 39/50, Loss: 0.0187, Accuracy: 0.9950
# Epoch 40/50, Loss: 0.0271, Accuracy: 0.9916
# Epoch 41/50, Loss: 0.0124, Accuracy: 0.9963
# Epoch 42/50, Loss: 0.0076, Accuracy: 0.9980
# Epoch 43/50, Loss: 0.0068, Accuracy: 0.9984
# Epoch 44/50, Loss: 0.0220, Accuracy: 0.9934
# Epoch 45/50, Loss: 0.0232, Accuracy: 0.9931
# Epoch 46/50, Loss: 0.0056, Accuracy: 0.9988
# Epoch 47/50, Loss: 0.0040, Accuracy: 0.9989
# Epoch 48/50, Loss: 0.0089, Accuracy: 0.9977
# Epoch 49/50, Loss: 0.0109, Accuracy: 0.9970
# Epoch 50/50, Loss: 0.0124, Accuracy: 0.9957
# Results: Train Loss: 0.0124, Train Accuracy: 0.9957, Test Accuracy: 0.7291
#
# Training with parameters: embed_dim=100, lstm_units=64, dropout_rate=0.3, learning_rate=0.0005
# Epoch 1/50, Loss: 1.9118, Accuracy: 0.2260
# Epoch 2/50, Loss: 1.6453, Accuracy: 0.3579
# Epoch 3/50, Loss: 1.4694, Accuracy: 0.4261
# Epoch 4/50, Loss: 1.3621, Accuracy: 0.4814
# Epoch 5/50, Loss: 1.2586, Accuracy: 0.5210
# Epoch 6/50, Loss: 1.1872, Accuracy: 0.5551
# Epoch 7/50, Loss: 1.0971, Accuracy: 0.5897
# Epoch 8/50, Loss: 1.0702, Accuracy: 0.6065
# Epoch 9/50, Loss: 1.0345, Accuracy: 0.6223
# Epoch 10/50, Loss: 1.0610, Accuracy: 0.6146
# Epoch 11/50, Loss: 0.9721, Accuracy: 0.6505
# Epoch 12/50, Loss: 0.8780, Accuracy: 0.6884
# Epoch 13/50, Loss: 0.8032, Accuracy: 0.7189
# Epoch 14/50, Loss: 0.7374, Accuracy: 0.7495
# Epoch 15/50, Loss: 0.6784, Accuracy: 0.7707
# Epoch 16/50, Loss: 0.6483, Accuracy: 0.7820
# Epoch 17/50, Loss: 0.5926, Accuracy: 0.8028
# Epoch 18/50, Loss: 0.6898, Accuracy: 0.7672
# Epoch 19/50, Loss: 0.6284, Accuracy: 0.7904
# Epoch 20/50, Loss: 0.5812, Accuracy: 0.8077
# Epoch 21/50, Loss: 0.5265, Accuracy: 0.8287
# Epoch 22/50, Loss: 0.4592, Accuracy: 0.8541
# Epoch 23/50, Loss: 0.4203, Accuracy: 0.8677
# Epoch 24/50, Loss: 0.3788, Accuracy: 0.8822
# Epoch 25/50, Loss: 0.3460, Accuracy: 0.8955
# Epoch 26/50, Loss: 0.3118, Accuracy: 0.9064
# Epoch 27/50, Loss: 0.2810, Accuracy: 0.9175
# Epoch 28/50, Loss: 0.2682, Accuracy: 0.9193
# Epoch 29/50, Loss: 0.2353, Accuracy: 0.9316
# Epoch 30/50, Loss: 0.2078, Accuracy: 0.9388
# Epoch 31/50, Loss: 0.1922, Accuracy: 0.9444
# Epoch 32/50, Loss: 0.1770, Accuracy: 0.9473
# Epoch 33/50, Loss: 0.1838, Accuracy: 0.9486
# Epoch 34/50, Loss: 0.1233, Accuracy: 0.9652
# Epoch 35/50, Loss: 0.1073, Accuracy: 0.9708
# Epoch 36/50, Loss: 0.0980, Accuracy: 0.9747
# Epoch 37/50, Loss: 0.1646, Accuracy: 0.9514
# Epoch 38/50, Loss: 0.0976, Accuracy: 0.9739
# Epoch 39/50, Loss: 0.0730, Accuracy: 0.9812
# Epoch 40/50, Loss: 0.0593, Accuracy: 0.9844
# Epoch 41/50, Loss: 0.0829, Accuracy: 0.9774
# Epoch 42/50, Loss: 0.0526, Accuracy: 0.9870
# Epoch 43/50, Loss: 0.0501, Accuracy: 0.9870
# Epoch 44/50, Loss: 0.0451, Accuracy: 0.9878
# Epoch 45/50, Loss: 0.0454, Accuracy: 0.9876
# Epoch 46/50, Loss: 0.0346, Accuracy: 0.9914
# Epoch 47/50, Loss: 0.0420, Accuracy: 0.9891
# Epoch 48/50, Loss: 0.0494, Accuracy: 0.9858
# Epoch 49/50, Loss: 0.0497, Accuracy: 0.9864
# Epoch 50/50, Loss: 0.0261, Accuracy: 0.9930
# Results: Train Loss: 0.0261, Train Accuracy: 0.9930, Test Accuracy: 0.7045
#
# Training with parameters: embed_dim=100, lstm_units=100, dropout_rate=0.2, learning_rate=0.001
# Epoch 1/50, Loss: 1.8407, Accuracy: 0.2668
# Epoch 2/50, Loss: 1.5639, Accuracy: 0.4085
# Epoch 3/50, Loss: 1.2546, Accuracy: 0.5199
# Epoch 4/50, Loss: 1.1026, Accuracy: 0.5963
# Epoch 5/50, Loss: 0.8989, Accuracy: 0.6932
# Epoch 6/50, Loss: 0.7199, Accuracy: 0.7561
# Epoch 7/50, Loss: 0.6119, Accuracy: 0.7957
# Epoch 8/50, Loss: 0.5068, Accuracy: 0.8335
# Epoch 9/50, Loss: 0.4775, Accuracy: 0.8456
# Epoch 10/50, Loss: 0.3755, Accuracy: 0.8788
# Epoch 11/50, Loss: 0.2883, Accuracy: 0.9111
# Epoch 12/50, Loss: 0.2254, Accuracy: 0.9321
# Epoch 13/50, Loss: 0.1696, Accuracy: 0.9502
# Epoch 14/50, Loss: 0.1294, Accuracy: 0.9628
# Epoch 15/50, Loss: 0.0932, Accuracy: 0.9744
# Epoch 16/50, Loss: 0.0842, Accuracy: 0.9748
# Epoch 17/50, Loss: 0.0551, Accuracy: 0.9853
# Epoch 18/50, Loss: 0.0579, Accuracy: 0.9826
# Epoch 19/50, Loss: 0.0460, Accuracy: 0.9862
# Epoch 20/50, Loss: 0.0582, Accuracy: 0.9827
# Epoch 21/50, Loss: 0.0397, Accuracy: 0.9883
# Epoch 22/50, Loss: 0.0384, Accuracy: 0.9878
# Epoch 23/50, Loss: 0.0266, Accuracy: 0.9917
# Epoch 24/50, Loss: 0.0124, Accuracy: 0.9965
# Epoch 25/50, Loss: 0.0159, Accuracy: 0.9951
# Epoch 26/50, Loss: 0.0345, Accuracy: 0.9891
# Epoch 27/50, Loss: 0.0269, Accuracy: 0.9909
# Epoch 28/50, Loss: 0.0241, Accuracy: 0.9930
# Epoch 29/50, Loss: 0.0120, Accuracy: 0.9967
# Epoch 30/50, Loss: 0.0104, Accuracy: 0.9969
# Epoch 31/50, Loss: 0.0240, Accuracy: 0.9929
# Epoch 32/50, Loss: 0.0244, Accuracy: 0.9921
# Epoch 33/50, Loss: 0.0124, Accuracy: 0.9964
# Epoch 34/50, Loss: 0.0105, Accuracy: 0.9969
# Epoch 35/50, Loss: 0.0195, Accuracy: 0.9934
